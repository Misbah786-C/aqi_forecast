# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("data/features/training_dataset.csv")
df
# Out:
#                 timestamp_utc  ow_temp  ow_pressure  ow_humidity  \
# 0   2025-10-22 09:05:02+00:00    36.07         1010           15
# 1   2025-10-22 12:00:00+00:00    35.32         1010           20
# 2   2025-10-22 15:00:00+00:00    33.31         1011           27
# 3   2025-10-22 18:00:00+00:00    30.98         1012           31
# 4   2025-10-22 21:00:00+00:00    28.41         1011           45
# 5   2025-10-23 00:00:00+00:00    28.49         1011           37
# 6   2025-10-23 03:00:00+00:00    29.27         1013           34
# 7   2025-10-23 06:00:00+00:00    32.85         1012           29
# 8   2025-10-23 09:00:00+00:00    33.58         1009           29
# 9   2025-10-23 12:00:00+00:00    32.59         1008           31
# 10  2025-10-23 15:00:00+00:00    30.00         1010           43
# 11  2025-10-23 18:00:00+00:00    28.56         1011           51
# 12  2025-10-23 21:00:00+00:00    27.75         1010           56
# 13  2025-10-24 00:00:00+00:00    27.22         1010           55
# 14  2025-10-24 03:00:00+00:00    28.82         1012           45
# 15  2025-10-24 06:00:00+00:00    31.64         1011           38
# 16  2025-10-24 09:00:00+00:00    31.74         1009           34
# 17  2025-10-24 12:00:00+00:00    31.27         1008           39
# 18  2025-10-24 15:00:00+00:00    29.73         1009           44
# 19  2025-10-24 18:00:00+00:00    28.74         1009           47
# 20  2025-10-24 21:00:00+00:00    27.99         1008           50
# 21  2025-10-25 00:00:00+00:00    27.78         1008           45
# 22  2025-10-25 03:00:00+00:00    29.33         1010           36
# 23  2025-10-25 06:00:00+00:00    32.57         1010           32
# 24  2025-10-25 09:00:00+00:00    32.35         1007           34
# 25  2025-10-25 12:00:00+00:00    31.90         1007           38
# 26  2025-10-25 15:00:00+00:00    29.40         1009           45
# 27  2025-10-25 18:00:00+00:00    28.68         1009           47
# 28  2025-10-25 21:00:00+00:00    28.86         1008           43
# 29  2025-10-26 00:00:00+00:00    28.39         1009           41
# 30  2025-10-26 03:00:00+00:00    29.24         1010           38
# 31  2025-10-26 06:00:00+00:00    32.42         1010           32
# 32  2025-10-26 09:00:00+00:00    33.37         1008           32
# 33  2025-10-26 12:00:00+00:00    33.39         1007           32
# 34  2025-10-26 15:00:00+00:00    30.01         1008           44
# 35  2025-10-26 18:00:00+00:00    29.24         1009           48
# 36  2025-10-26 21:00:00+00:00    28.79         1009           43
# 37  2025-10-27 00:00:00+00:00    28.48         1009           39
# 38  2025-10-27 03:00:00+00:00    28.84         1010           39
# 39  2025-10-27 06:00:00+00:00    31.31         1011           33
# 40  2025-10-27 09:00:00+00:00    31.40         1008           35
#
#     ow_wind_speed  ow_wind_deg  ow_clouds   ow_co  ow_no  ow_no2  ...  \
# 0            4.12           40          0  419.18   0.19    2.59  ...
# 1            4.11           62          0     NaN    NaN     NaN  ...
# 2            3.21           18          0     NaN    NaN     NaN  ...
# 3            4.78           58          0     NaN    NaN     NaN  ...
# 4            0.32          122          0     NaN    NaN     NaN  ...
# 5            3.33          350          0     NaN    NaN     NaN  ...
# 6            4.04           21          0     NaN    NaN     NaN  ...
# 7            2.60           57          0     NaN    NaN     NaN  ...
# 8            1.05          237          0     NaN    NaN     NaN  ...
# 9            3.18          273          0     NaN    NaN     NaN  ...
# 10           2.98          282          1     NaN    NaN     NaN  ...
# 11           3.56          253          2     NaN    NaN     NaN  ...
# 12           4.10          293          2     NaN    NaN     NaN  ...
# 13           1.92          334          1     NaN    NaN     NaN  ...
# 14           1.03          340          0     NaN    NaN     NaN  ...
# 15           0.40          256          0     NaN    NaN     NaN  ...
# 16           3.16          226          1     NaN    NaN     NaN  ...
# 17           5.96          278          1     NaN    NaN     NaN  ...
# 18           3.59          315          0     NaN    NaN     NaN  ...
# 19           2.94          237          0     NaN    NaN     NaN  ...
# 20           3.82          313          0     NaN    NaN     NaN  ...
# 21           2.27          344          0     NaN    NaN     NaN  ...
# 22           1.70           44          0     NaN    NaN     NaN  ...
# 23           2.22          122          0     NaN    NaN     NaN  ...
# 24           3.63          207          0     NaN    NaN     NaN  ...
# 25           3.16          259          0     NaN    NaN     NaN  ...
# 26           2.57          245          0     NaN    NaN     NaN  ...
# 27           1.80          191          0     NaN    NaN     NaN  ...
# 28           3.38          338         60     NaN    NaN     NaN  ...
# 29           3.51            6         67     NaN    NaN     NaN  ...
# 30           3.05           65          7     NaN    NaN     NaN  ...
# 31           2.84           98          5     NaN    NaN     NaN  ...
# 32           2.69          115          0     NaN    NaN     NaN  ...
# 33           2.19           36          0     NaN    NaN     NaN  ...
# 34           2.37          220         54     NaN    NaN     NaN  ...
# 35           0.79          224         72     NaN    NaN     NaN  ...
# 36           0.97           28         97     NaN    NaN     NaN  ...
# 37           3.13           26         89     NaN    NaN     NaN  ...
# 38           2.79           24         78     NaN    NaN     NaN  ...
# 39           3.04          130         69     NaN    NaN     NaN  ...
# 40           3.26          199         65     NaN    NaN     NaN  ...
#
#     aqicn_co  aqicn_no2  aqicn_pm25  aqicn_pm10  aqicn_o3  aqicn_so2  hour  \
# 0        7.3        6.5        95.0        59.0      32.2        3.4     9
# 1        NaN        NaN         NaN         NaN       NaN        NaN    12
# 2        NaN        NaN         NaN         NaN       NaN        NaN    15
# 3        NaN        NaN         NaN         NaN       NaN        NaN    18
# 4        NaN        NaN         NaN         NaN       NaN        NaN    21
# 5        NaN        NaN         NaN         NaN       NaN        NaN     0
# 6        NaN        NaN         NaN         NaN       NaN        NaN     3
# 7        NaN        NaN         NaN         NaN       NaN        NaN     6
# 8        NaN        NaN         NaN         NaN       NaN        NaN     9
# 9        NaN        NaN         NaN         NaN       NaN        NaN    12
# 10       NaN        NaN         NaN         NaN       NaN        NaN    15
# 11       NaN        NaN         NaN         NaN       NaN        NaN    18
# 12       NaN        NaN         NaN         NaN       NaN        NaN    21
# 13       NaN        NaN         NaN         NaN       NaN        NaN     0
# 14       NaN        NaN         NaN         NaN       NaN        NaN     3
# 15       NaN        NaN         NaN         NaN       NaN        NaN     6
# 16       NaN        NaN         NaN         NaN       NaN        NaN     9
# 17       NaN        NaN         NaN         NaN       NaN        NaN    12
# 18       NaN        NaN         NaN         NaN       NaN        NaN    15
# 19       NaN        NaN         NaN         NaN       NaN        NaN    18
# 20       NaN        NaN         NaN         NaN       NaN        NaN    21
# 21       NaN        NaN         NaN         NaN       NaN        NaN     0
# 22       NaN        NaN         NaN         NaN       NaN        NaN     3
# 23       NaN        NaN         NaN         NaN       NaN        NaN     6
# 24       NaN        NaN         NaN         NaN       NaN        NaN     9
# 25       NaN        NaN         NaN         NaN       NaN        NaN    12
# 26       NaN        NaN         NaN         NaN       NaN        NaN    15
# 27       NaN        NaN         NaN         NaN       NaN        NaN    18
# 28       NaN        NaN         NaN         NaN       NaN        NaN    21
# 29       NaN        NaN         NaN         NaN       NaN        NaN     0
# 30       NaN        NaN         NaN         NaN       NaN        NaN     3
# 31       NaN        NaN         NaN         NaN       NaN        NaN     6
# 32       NaN        NaN         NaN         NaN       NaN        NaN     9
# 33       NaN        NaN         NaN         NaN       NaN        NaN    12
# 34       NaN        NaN         NaN         NaN       NaN        NaN    15
# 35       NaN        NaN         NaN         NaN       NaN        NaN    18
# 36       NaN        NaN         NaN         NaN       NaN        NaN    21
# 37       NaN        NaN         NaN         NaN       NaN        NaN     0
# 38       NaN        NaN         NaN         NaN       NaN        NaN     3
# 39       NaN        NaN         NaN         NaN       NaN        NaN     6
# 40       NaN        NaN         NaN         NaN       NaN        NaN     9
#
#     day  month  weekday
# 0    22     10        2
# 1    22     10        2
# 2    22     10        2
# 3    22     10        2
# 4    22     10        2
# 5    23     10        3
# 6    23     10        3
# 7    23     10        3
# 8    23     10        3
# 9    23     10        3
# 10   23     10        3
# 11   23     10        3
# 12   23     10        3
# 13   24     10        4
# 14   24     10        4
# 15   24     10        4
# 16   24     10        4
# 17   24     10        4
# 18   24     10        4
# 19   24     10        4
# 20   24     10        4
# 21   25     10        5
# 22   25     10        5
# 23   25     10        5
# 24   25     10        5
# 25   25     10        5
# 26   25     10        5
# 27   25     10        5
# 28   25     10        5
# 29   26     10        6
# 30   26     10        6
# 31   26     10        6
# 32   26     10        6
# 33   26     10        6
# 34   26     10        6
# 35   26     10        6
# 36   26     10        6
# 37   27     10        0
# 38   27     10        0
# 39   27     10        0
# 40   27     10        0
#
# [41 rows x 26 columns]

# %%
# Convert timestamp to datetime
df['timestamp_utc'] = pd.to_datetime(df['timestamp_utc'])

# %%
# Forward-fill missing values
df = df.fillna(method='ffill')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8000\306281980.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')

# %%
# Select only numeric columns for correlation
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df_numeric = df[numeric_cols]

# %%
# Plot correlation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df_numeric.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Sort by timestamp
df = df.sort_values('timestamp_utc')

# %%
# Select numeric columns only
numeric_cols = df_ffill.select_dtypes(include=['float64', 'int64']).columns
df_numeric = df_ffill[numeric_cols]

print(df_numeric.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Select numeric columns only
# ----> 2 numeric_cols = df_ffill.select_dtypes(include=['float64', 'int64']).columns
#       3 df_numeric = df_ffill[numeric_cols]
#       5 print(df_numeric.head())
#
# NameError: name 'df_ffill' is not defined
